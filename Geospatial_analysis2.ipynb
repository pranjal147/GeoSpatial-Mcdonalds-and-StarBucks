# %%
import pandas as pd
import numpy as np
import folium
import geopy.distance

# %%
#Read file containing location details
df = pd.read_csv('https://drive.google.com/uc?id=19JERBe0ndadkMPKDFZ0rTEZqdI50zDfk')
df.head(10)
# Out:
#          lat        lng      store                                 address
# 0  40.711000 -74.000878  Starbucks        375 Pearl st, New York, NY 10038
# 1  40.707142 -74.004987  Starbucks     135 John Street, New York, NY 10038
# 2  40.708411 -74.007404  Starbucks  100 William Street, New York, NY 10038
# 3  40.711644 -74.006667  Starbucks     38 Park Row, #4, New York, NY 10038
# 4  40.710171 -74.007931  Starbucks   130 Fulton Street, New York, NY 10038
# 5  40.706316 -74.006582  Starbucks      80 Pine Street, New York, NY 10005
# 6  40.712208 -74.008192  Starbucks        233 Broadway, New York, NY 10279
# 7  40.708742 -74.009508  Starbucks   55 Liberty Street, New York, NY 10005
# 8  40.706033 -74.008348  Starbucks          60 Wall St, New York, NY 10005
# 9  40.704817 -74.007231  Starbucks         99 Wall St., New York, NY 10005

# %%
#Merge Columns
df['Coordinate'] = '(' + df['lat'].astype(str) + ', ' + df['lng'].astype(str) + ')'
df.head(10)
# Out:
#          lat        lng      store                                 address  \
# 0  40.711000 -74.000878  Starbucks        375 Pearl st, New York, NY 10038
# 1  40.707142 -74.004987  Starbucks     135 John Street, New York, NY 10038
# 2  40.708411 -74.007404  Starbucks  100 William Street, New York, NY 10038
# 3  40.711644 -74.006667  Starbucks     38 Park Row, #4, New York, NY 10038
# 4  40.710171 -74.007931  Starbucks   130 Fulton Street, New York, NY 10038
# 5  40.706316 -74.006582  Starbucks      80 Pine Street, New York, NY 10005
# 6  40.712208 -74.008192  Starbucks        233 Broadway, New York, NY 10279
# 7  40.708742 -74.009508  Starbucks   55 Liberty Street, New York, NY 10005
# 8  40.706033 -74.008348  Starbucks          60 Wall St, New York, NY 10005
# 9  40.704817 -74.007231  Starbucks         99 Wall St., New York, NY 10005
#
#                 Coordinate
# 0     (40.711, -74.000878)
# 1  (40.707142, -74.004987)
# 2  (40.708411, -74.007404)
# 3  (40.711644, -74.006667)
# 4  (40.710171, -74.007931)
# 5  (40.706316, -74.006582)
# 6  (40.712208, -74.008192)
# 7  (40.708742, -74.009508)
# 8  (40.706033, -74.008348)
# 9  (40.704817, -74.007231)

# %%
#New York Empire State Building Lat Long (Looking for any approx center point)
NY_coord = (40.748488, -73.985238)

# %%
#Compute distance of every store from city center
distances_km = []

for row in df.itertuples(index=False):
   distances_km.append(
       geopy.distance.distance(NY_coord, row.Coordinate).km
   )

df['Distance'] = distances_km
df.head(10)
# Out:
#          lat        lng      store                                 address  \
# 0  40.711000 -74.000878  Starbucks        375 Pearl st, New York, NY 10038
# 1  40.707142 -74.004987  Starbucks     135 John Street, New York, NY 10038
# 2  40.708411 -74.007404  Starbucks  100 William Street, New York, NY 10038
# 3  40.711644 -74.006667  Starbucks     38 Park Row, #4, New York, NY 10038
# 4  40.710171 -74.007931  Starbucks   130 Fulton Street, New York, NY 10038
# 5  40.706316 -74.006582  Starbucks      80 Pine Street, New York, NY 10005
# 6  40.712208 -74.008192  Starbucks        233 Broadway, New York, NY 10279
# 7  40.708742 -74.009508  Starbucks   55 Liberty Street, New York, NY 10005
# 8  40.706033 -74.008348  Starbucks          60 Wall St, New York, NY 10005
# 9  40.704817 -74.007231  Starbucks         99 Wall St., New York, NY 10005
#
#                 Coordinate  Distance
# 0     (40.711, -74.000878)  4.367628
# 1  (40.707142, -74.004987)  4.885149
# 2  (40.708411, -74.007404)  4.828401
# 3  (40.711644, -74.006667)  4.474066
# 4  (40.710171, -74.007931)  4.666971
# 5  (40.706316, -74.006582)  5.018288
# 6  (40.712208, -74.008192)  4.471204
# 7  (40.708742, -74.009508)  4.866712
# 8  (40.706033, -74.008348)  5.102829
# 9  (40.704817, -74.007231)  5.193348

# %%
#Empire State Building coordinates
m = folium.Map(location=[40.748488, -73.985238], zoom_start= 10)

#Place markers for the stores on the map
for i, row in df.iterrows():
  lat = df.at[i, 'lat']
  lng = df.at[i, 'lng']
  store = df.at[i, 'store']

  if store == 'McDonalds':
    color = 'blue'
  else:
    color = 'green'

  folium.Marker(location=[lat,lng], popup=store, icon= folium.Icon(color=color)).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_24afc0d94e9820ce7e27f264576930b2 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_24afc0d94e9820ce7e27f264576930b2&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_24afc0d94e9820ce7e27f264576930b2 = L.map(
#                 &quot;map_24afc0d94e9820ce7e27f264576930b2&quot;,
#                 {
#                     center: [40.748488, -73.985238],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_dace21ce9ea99e3a2728c0a0b4967d80 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_24afc0d94e9820ce7e27f264576930b2);
#
#
#             var marker_c478499a5973b91c9206da2e2c9f7349 = L.marker(
#                 [40.711, -74.000878],
#                 {}
#             ).addTo(map_24afc0d94e9820ce7e27f264576930b2);
#
#
#             var icon_25f605b7a711f615e8c0061cde9f89c8 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_c478499a5973b91c9206da2e2c9f7349.setIcon(icon_25f605b7a711f615e8c0061cde9f89c8);
#
#
#         var popup_b12ce0d899105b572bdcf4a93b714950 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_9f2a94310f303b6da7d6774a466b9963 = $(`&lt;div id=&quot;html_9f2a94310f303b6da7d6774a466b9963&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Starbucks&lt;/div&gt;`)[0];
#             popup_b12ce0d899105b572bdcf4a93b714950.setContent(html_9f2a94310f303b6da7d6774a466b9963);
#
#
#         marker_c478499a5973b91c9206da2e2c9f7349.bindPopup(popup_b12ce0d899105b572bdcf4a93b714950)
#         ;
#
#
#
#
#             var marker_0e77cd406f22c9c0344c6ac9734406fb = L.marker(
#                 [40.707142, -74.004987],
#                 {}
#             ).addTo(map_24afc0d94e9820ce7e27f264576930b2);
#
#
#             var icon_bdd1d48cefcf10a4489dfed49a5cbabe = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_0e77cd406f22c9c0344c6ac9734406fb.setIcon(icon_bdd1d48cefcf10a4489dfed49a5cbabe);
#
#
#         var popup_2a31aa892f623e19240daf3f3094ad7b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_8ce0034851a2e0f39ae1a1fde6ec25f4 = $(`&lt;div id=&quot;html_8ce0034851a2e0f39ae1a1fde6ec25f4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Starbucks&lt;/div&gt;`)[0];
#             popup_2a31aa892f623e19240daf3f3094ad7b.setContent(html_8ce0034851a2e0f39ae1a1fde6ec25f4);
#
#
#         marker_0e77cd406f22c9c0344c6ac9734406fb.bindPopup(popup_2a31aa892f623e19240daf3f3094ad7b)
#         ;
#
#
#
#
#             var marker_c9f6eb771b50d36b8dad4562cc452620 = L.marker(
#                 [40.708411, -74.007404],
#                 {}
#             ).addTo(map_24afc0d94e9820ce7e27f264576930b2);
#
#
#             var icon_3ff62c37cf70c25beb89f4caaea8199f = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_c9f6eb771b50d36b8dad4562cc452620.setIcon(icon_3ff62c37cf70c25beb89f4caaea8199f);
#
#
#         var popup_6159460e84017f1115a42d8eaee23014 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_cffae601662dc667f11b851174dc87e3 = $(`&lt;div id=&quot;html_cffae601662dc667f11b851174dc87e3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Starbucks&lt;/div&gt;`)[0];
#             popup_6159460e84017f1115a42d8eaee23014.setContent(html_cffae601662dc667f11b851174dc87e3);
#
#
#         marker_c9f6eb771b50d36b8dad4562cc452620.bindPopup(popup_6159460e84017f1115a42d8eaee23014)
#         ;
#
#
#
#
#             var marker_ba21faeb0558b5348368ce93d08496bc = L.marker(
#                 [40.711644, -74.006667],
#                 {}
#             ).addTo(map_24afc0d94e9820ce7e27f264576930b2);
#
#
#             var icon_f898db213b703b2c5517c6d1fbade919 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_ba21faeb0558b5348368ce93d08496bc.setIcon(icon_f898db213b703b2c5517c6d

# %%
#All stores at a distance greater/less than x kms
df[df['Distance'] > 10]
# Out:
#            lat        lng      store  \
# 227  40.841350 -73.939822  Starbucks
# 228  40.841723 -73.941375  Starbucks
# 229  40.851000 -73.938421  Starbucks
# 230  40.865721 -73.927287  Starbucks
# 273  40.835319 -73.944335  McDonalds
# 277  40.842594 -73.938972  McDonalds
# 280  40.850094 -73.936035  McDonalds
# 286  40.865080 -73.927202  McDonalds
# 287  40.867396 -73.921301  McDonalds
#
#                                           address               Coordinate  \
# 227             4001 Broadway, New York, NY 10032   (40.84135, -73.939822)
# 228  177 Fort Washington Ave , New York, NY 10032  (40.841723, -73.941375)
# 229            803 W 181st St, New York, NY 10033     (40.851, -73.938421)
# 230             4761 Broadway, New York, NY 10040  (40.865721, -73.927287)
# 273                                 3809 BROADWAY  (40.835319, -73.944335)
# 277                                 4040 BROADWAY  (40.842594, -73.938972)
# 280                                 4259 BROADWAY  (40.850094, -73.936035)
# 286                                208 DYCKMAN ST   (40.86508, -73.927202)
# 287                         608 WEST 207TH STREET  (40.867396, -73.921301)
#
#       Distance
# 227  11.001594
# 228  10.995612
# 229  12.050055
# 230  13.906793
# 273  10.241912
# 277  11.156082
# 280  12.023104
# 286  13.842721
# 287  14.264323

# %%
df_farthest = df.iloc[df.groupby('store')['Distance'].agg(pd.Series.idxmax)]
df_closest = df.iloc[df.groupby('store')['Distance'].agg(pd.Series.idxmin)]
df_new = pd.concat([df_farthest, df_closest])

# %%
df_closest
# Out:
#            lat        lng      store                               address  \
# 256  40.750816 -73.986819  McDonalds                           972 6TH AVE
# 110  40.748660 -73.985614  Starbucks  350 Fifth Avenue, New York, NY 10118
#
#                   Coordinate  Distance
# 256  (40.750816, -73.986819)  0.290966
# 110   (40.74866, -73.985614)  0.037057

# %%
df_new
# Out:
#            lat        lng      store                               address  \
# 287  40.867396 -73.921301  McDonalds                 608 WEST 207TH STREET
# 230  40.865721 -73.927287  Starbucks     4761 Broadway, New York, NY 10040
# 256  40.750816 -73.986819  McDonalds                           972 6TH AVE
# 110  40.748660 -73.985614  Starbucks  350 Fifth Avenue, New York, NY 10118
#
#                   Coordinate   Distance
# 287  (40.867396, -73.921301)  14.264323
# 230  (40.865721, -73.927287)  13.906793
# 256  (40.750816, -73.986819)   0.290966
# 110   (40.74866, -73.985614)   0.037057

# %%
df_farthest
# Out:
#            lat        lng      store                            address  \
# 287  40.867396 -73.921301  McDonalds              608 WEST 207TH STREET
# 230  40.865721 -73.927287  Starbucks  4761 Broadway, New York, NY 10040
#
#                   Coordinate   Distance
# 287  (40.867396, -73.921301)  14.264323
# 230  (40.865721, -73.927287)  13.906793

# %%
#Empire State Building coordinates
m = folium.Map(location=[40.748488, -73.985238], zoom_start= 10)

for i, rown in df_new.iterrows():
  lat = df_new.at[i, 'lat']
  lng = df_new.at[i, 'lng']
  store = df_new.at[i, 'store']

  if store == 'McDonalds':
    color = 'blue'
  else:
    color = 'green'

  folium.Marker(location=[lat,lng], popup=store, icon= folium.Icon(color=color)).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_931175bba29d6c3cd022e8101c4caf17 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_931175bba29d6c3cd022e8101c4caf17&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_931175bba29d6c3cd022e8101c4caf17 = L.map(
#                 &quot;map_931175bba29d6c3cd022e8101c4caf17&quot;,
#                 {
#                     center: [40.748488, -73.985238],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_645170a0b58ec8e13b36c660dc42b861 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_931175bba29d6c3cd022e8101c4caf17);
#
#
#             var marker_443b640b1b7269a5fc88e628199c1425 = L.marker(
#                 [40.867396, -73.921301],
#                 {}
#             ).addTo(map_931175bba29d6c3cd022e8101c4caf17);
#
#
#             var icon_8fa7a4be9492b3a1619e2ae33f5f3cb2 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_443b640b1b7269a5fc88e628199c1425.setIcon(icon_8fa7a4be9492b3a1619e2ae33f5f3cb2);
#
#
#         var popup_3f1e7fffd0d07bb07203f5848e5e301e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_b5a1a0f380b1c0acfc7635a813c011d3 = $(`&lt;div id=&quot;html_b5a1a0f380b1c0acfc7635a813c011d3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;McDonalds&lt;/div&gt;`)[0];
#             popup_3f1e7fffd0d07bb07203f5848e5e301e.setContent(html_b5a1a0f380b1c0acfc7635a813c011d3);
#
#
#         marker_443b640b1b7269a5fc88e628199c1425.bindPopup(popup_3f1e7fffd0d07bb07203f5848e5e301e)
#         ;
#
#
#
#
#             var marker_28662f9d0efbcb1a887cf5d6ff2a3057 = L.marker(
#                 [40.865721, -73.927287],
#                 {}
#             ).addTo(map_931175bba29d6c3cd022e8101c4caf17);
#
#
#             var icon_065448da5814698059f1c4562dda7d7e = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_28662f9d0efbcb1a887cf5d6ff2a3057.setIcon(icon_065448da5814698059f1c4562dda7d7e);
#
#
#         var popup_8e65e3212c12de65137a178088952916 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_d3bd51e2a826ffa69e0216a8f4d4baef = $(`&lt;div id=&quot;html_d3bd51e2a826ffa69e0216a8f4d4baef&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Starbucks&lt;/div&gt;`)[0];
#             popup_8e65e3212c12de65137a178088952916.setContent(html_d3bd51e2a826ffa69e0216a8f4d4baef);
#
#
#         marker_28662f9d0efbcb1a887cf5d6ff2a3057.bindPopup(popup_8e65e3212c12de65137a178088952916)
#         ;
#
#
#
#
#             var marker_a6c3b03f9ea0cc3dce47fac4b8e4c6bb = L.marker(
#                 [40.750816, -73.986819],
#                 {}
#             ).addTo(map_931175bba29d6c3cd022e8101c4caf17);
#
#
#             var icon_a3c9f44d94d7a1363f6ec834abb8f136 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_a6c3b03f9ea0cc3dce47fac4b8e4c6bb.setIcon(icon_a3c9f44d94d7a1363f6ec834abb8f136);
#
#
#         var popup_04060c9c71550204d075bc73f9d4fe74 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_008c0a05b98fa092a68a863952cab4a1 = $(`&lt;div id=&quot;html_008c0a05b98fa092a68a863952cab4a1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;McDonalds&lt;/div&gt;`)[0];
#             popup_04060c9c71550204d075bc73f9d4fe74.setContent(html_008c0a05b98fa092a68a863952cab4a1);
#
#
#         marker_a6c3b03f9ea0cc3dce47fac4b8e4c6bb.bindPopup(popup_04060c9c71550204d075bc73f9d4fe74)
#         ;
#
#
#
#
#             var marker_3b574ea545370885f3e6ae76e9df2df3 = L.marker(
#                 [40.74866, -73.985614],
#                 {}
#             ).addTo(map_931175bba29d6c3cd022e8101c4caf17);
#
#
#             var icon_ad02b62a8522b38087e5186ef69ad5df = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_3b574ea545370885f3e6ae76e9df2df3.setIcon(icon_ad02b62a8522b38087e5186
